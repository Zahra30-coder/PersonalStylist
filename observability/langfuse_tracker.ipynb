# %%
from langfuse import Langfuse
from langfuse.decorators import observe, langfuse_context
from app.tools.gemini_tool import chat_with_memory
from dotenv import load_dotenv
import os
import sys
# Out:
# At line:2 char:1
# + from langfuse import Langfuse, get_client, observe
# + ~~~~
# The 'from' keyword is not supported in this version of the language.
# At line:3 char:1
# + from tools.gemin_tools import response
# + ~~~~
# The 'from' keyword is not supported in this version of the language.
# At line:4 char:1
# + from dotenv import load_dotenv
# + ~~~~
# The 'from' keyword is not supported in this version of the language.
#     + CategoryInfo          : ParserError: (:) [], ParentContainsErrorRecordException
#     + FullyQualifiedErrorId : ReservedKeywordNotAllowed

# %%
print(sys.executable)

# %%
langfuse = Langfuse()
# Out:
# At line:2 char:21
# + langfuse = Langfuse()
# +                     ~
# An expression was expected after '('.
#     + CategoryInfo          : ParserError: (:) [], ParentContainsErrorRecordException
#     + FullyQualifiedErrorId : ExpectedExpression

# %%
# Load .env from parent directory
load_dotenv(r"D:\CHATBOT\.env")

# Get API key
api_key = os.getenv("LANGFUSE_SECRET_KEY")
api_key = os.getenv("LANGFUSE_SECRET_KEY")
api_key = os.getenv("LANGFUSE_SECRET_KEY")
# Out:
# rD:\CHATBOT\chatbot-env : The term 'rD:\CHATBOT\chatbot-env' is not recognized as the name of a cmdlet, function,
# script file, or operable program. Check the spelling of the name, or if a path was included, verify that the path is
# correct and try again.
# At line:3 char:13
# + load_dotenv(r"D:\CHATBOT\chatbot-env")
# +             ~~~~~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : ObjectNotFound: (rD:\CHATBOT\chatbot-env:String) [], CommandNotFoundException
#     + FullyQualifiedErrorId : CommandNotFoundException
#
# api_key : The term 'api_key' is not recognized as the name of a cmdlet, function, script file, or operable program.
# Check the spelling of the name, or if a path was included, verify that the path is correct and try again.
# At line:5 char:1
# + api_key = os.getenv("LANGFUSE_SECRET_KEY")
# + ~~~~~~~
#     + CategoryInfo          : ObjectNotFound: (api_key:String) [], CommandNotFoundException
#     + FullyQualifiedErrorId : CommandNotFoundException
#
# ...

# %%
@observe(capture_input=True, capture_output=True)
def test():
    return "hello"

test()
# Out:
# . {
# >> @observe()
# >> def test():
# >>     return "hello"
# >>
# At line:2 char:9
# + @observe()
# +         ~
# Unexpected token '(' in expression or statement.
# At line:2 char:10
# + @observe()
# +          ~
# An expression was expected after '('.
# At line:3 char:10
# + def test():
# +          ~
# An expression was expected after '('.
# At line:1 char:3
# + . {
# +   ~
# Missing closing '}' in statement block or type definition.
# At line:2 char:1
# + @observe()
# + ~~~~~~~~
# The splatting operator '@' cannot be used to reference variables in an expression. '@observe' can be used only as an
# argument to a command. To reference variables in an expression use '$observe'.
#     + CategoryInfo          : ParserError: (:) [], ParentContainsErrorRecordException
#     + FullyQualifiedErrorId : UnexpectedToken
#
# test()

# %%
LANGFUSE_SECRET_KEY="sk-lf-e2ab9738-c358-47d8-b4b1-684bea17a84c"
LANGFUSE_PUBLIC_KEY="pk-lf-248fc879-5504-45cd-a98c-60a5625e7df9"
LANGFUSE_BASE_URL="https://us.cloud.langfuse.com"
# Out:
# At line:1 char:6
# + test()
# +      ~
# An expression was expected after '('.
#     + CategoryInfo          : ParserError: (:) [], ParentContainsErrorRecordException
#     + FullyQualifiedErrorId : ExpectedExpression
#
# }
# At line:1 char:1
# + }
# + ~
# Unexpected token '}' in expression or statement.
#     + CategoryInfo          : ParserError: (:) [], ParentContainsErrorRecordException
#     + FullyQualifiedErrorId : UnexpectedToken
#
#
# . {
# >> LANGFUSE_SECRET_KEY="sk-lf-e2ab9738-c358-47d8-b4b1-684bea17a84c"
# >> LANGFUSE_PUBLIC_KEY="pk-lf-248fc879-5504-45cd-a98c-60a5625e7df9"
# >> LANGFUSE_BASE_URL="https://us.cloud.langfuse.com"
# >> }
# >>
# LANGFUSE_SECRET_KEY=sk-lf-e2ab9738-c358-47d8-b4b1-684bea17a84c : The term
# 'LANGFUSE_SECRET_KEY=sk-lf-e2ab9738-c358-47d8-b4b1-684bea17a84c' is not recognized as the name of a cmdlet, function,
# script file, or operable program. Check the spelling of the name, or if a path was included, verify that the path is
# ...
